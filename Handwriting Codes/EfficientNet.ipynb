# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, datasets
from tensorflow.keras.optimizers import SGD

# %%
# !unzip "/content/sample_data/spiral.zip" -d "/content/sample_data/"

# %%
# Set the path to your training and testing directories
train_dir = '/content/sample_data/spiral/train'
test_dir = '/content/sample_data/spiral/val'

# Define image dimensions and batch size
img_width, img_height = 224, 224  # You can adjust these dimensions based on your images
batch_size = 32

# Create data generators for training and testing sets
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=60,  # Random rotations up to 60 degrees
    width_shift_range=0.2,  # Random shifts up to 20% of the image width
    height_shift_range=0.2,  # Random shifts up to 20% of the image height
    zoom_range=0.2,   # Random zooms up to 20%
    horizontal_flip=True)   # Normalize pixel values between 0 and 1)

test_datagen = ImageDataGenerator(rescale=1./255)  # Only rescaling for the testing set

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'  # Change to 'categorical' if you have more than two classes
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 198 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %%
def plot_images(images, labels):
    num_images = len(images)
    rows = int(np.sqrt(num_images))
    cols = int(np.ceil(num_images / rows))

    plt.figure(figsize=(10, 10))

    for i in range(num_images):
        plt.subplot(rows, cols, i+1)
        plt.imshow(images[i])
        plt.title(f"Label: {np.argmax(labels[i])}")
        plt.axis('off')

    plt.show()

# %%
images, labels = train_generator.next()
plot_images(images, labels)

# %%
base_model = tf.keras.applications.EfficientNetB0(weights=None, include_top=False, input_shape=(224, 224, 3))

# %%
for layer in base_model.layers :
  layer.trainable=False

# %%
model = models.Sequential()
model.add(base_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(2, activation='sigmoid'))

# %%
sgd = tf.keras.optimizers.legacy.SGD(learning_rate=0.0001, momentum=0.9, decay=0.0005)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
batch_size = 32

model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=10,# You can adjust the number of epochs
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size,

)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 67s 9s/step - loss: 0.7171 - accuracy: 0.5060 - val_loss: 0.6929 - val_accuracy: 0.5312
# Epoch 2/10
# 6/6 [==============================] - 48s 9s/step - loss: 0.7350 - accuracy: 0.4880 - val_loss: 0.6936 - val_accuracy: 0.4688
# Epoch 3/10
# 6/6 [==============================] - 49s 8s/step - loss: 0.7173 - accuracy: 0.4759 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/10
# 6/6 [==============================] - 49s 8s/step - loss: 0.6798 - accuracy: 0.5000 - val_loss: 0.6946 - val_accuracy: 0.4062
# Epoch 5/10
# 6/6 [==============================] - 49s 8s/step - loss: 0.7085 - accuracy: 0.5361 - val_loss: 0.6918 - val_accuracy: 0.6562
# Epoch 6/10
# 6/6 [==============================] - 55s 9s/step - loss: 0.6966 - accuracy: 0.5938 - val_loss: 0.6932 - val_accuracy: 0.4688
# Epoch 7/10
# 6/6 [==============================] - 49s 9s/step - loss: 0.6898 - accuracy: 0.5482 - val_loss: 0.6928 - val_accuracy: 0.5312
# Epoch 8/10
# 6/6 [==============================] - 49s 8s/step - loss: 0.6603 - accuracy: 0.6145 - val_loss: 0.6940 - val_accuracy: 0.4688
# Epoch 9/10
# 6/6 [==============================] - 50s 8s/step - loss: 0.6660 - accuracy: 0.5904 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 10/10
# 6/6 [==============================] - 50s 8s/step - loss: 0.6399 - accuracy: 0.5663 - val_loss: 0.6973 - val_accuracy: 0.4375

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# 2/2 [==============================] - 4s 1s/step - loss: 0.6812 - accuracy: 0.5000
# Test Loss: 0.6811785697937012, Test Accuracy: 0.5

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 22327842 (85.17 MB)
# Trainable params: 22293410 (85.04 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
